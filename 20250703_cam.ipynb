# %%
import cv2

# %%
capture = cv2.VideoCapture(0)
capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
# Out:
# True

# %%
capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
# Out:
# True

# %%
while True:
    ret, frame = capture.read()
    if not ret:
        print("카메라 오류")
        break
    cv2.imshow("VideoFrame", frame)

    if cv2.waitKey(1000) & 0xFF == ord('q'):
        break
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
text = "Smile!!"
position = (30,50)
font = cv2.FONT_HERSHEY_SIMPLEX
scale = 1
color = (255,255,255)
thickness = 2

# %%
while True:
    ret, frame = capture.read()
    cv2.putText(frame, text, position, font, scale, color, thickness)
    if not ret:
        print("카메라 오류")
        break
    print(type(frame))
    cv2.imshow("VideoFrame", frame)


    if cv2.waitKey(10) & 0xFF == ord('q'):
        capture.release()
        cv2.destroyAllWindows()
        break

# %%
from ultralytics import YOLO
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from ultralytics import YOLO
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\__init__.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 __version__ = '8.0.128'
# ----> 5 from ultralytics.hub import start
#       6 from ultralytics.vit.rtdetr import RTDETR
#       7 from ultralytics.vit.sam import SAM
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\hub\__init__.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 import requests
# ----> 5 from ultralytics.hub.auth import Auth
#       6 from ultralytics.hub.utils import PREFIX
#       7 from ultralytics.yolo.data.utils import HUBDatasetStats
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\hub\auth.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 import requests
# ----> 5 from ultralytics.hub.utils import HUB_API_ROOT, PREFIX, request_with_credentials
#       6 from ultralytics.yolo.utils import LOGGER, SETTINGS, emojis, is_colab, set_settings
#       8 API_KEY_URL = 'https://hub.ultralytics.com/settings?tab=api+keys'
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\hub\utils.py:14
#      11 import requests
#      12 from tqdm import tqdm
# ---> 14 from ultralytics.yolo.utils import (ENVIRONMENT, LOGGER, ONLINE, RANK, SETTINGS, TESTS_RUNNING, TQDM_BAR_FORMAT,
#      15                                     TryExcept, __version__, colorstr, get_git_origin_url, is_colab, is_git_dir,
#      16                                     is_pip_package)
#      18 PREFIX = colorstr('Ultralytics HUB: ')
#      19 HELP_MSG = 'If this issue persists please visit https://github.com/ultralytics/hub/issues for assistance.'
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from . import v8
#       5 __all__ = 'v8',  # tuple or list
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\v8\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from ultralytics.yolo.v8 import classify, detect, pose, segment
#       5 __all__ = 'classify', 'segment', 'detect', 'pose'
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\v8\classify\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from ultralytics.yolo.v8.classify.predict import ClassificationPredictor, predict
#       4 from ultralytics.yolo.v8.classify.train import ClassificationTrainer, train
#       5 from ultralytics.yolo.v8.classify.val import ClassificationValidator, val
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\v8\classify\predict.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 import torch
# ----> 5 from ultralytics.yolo.engine.predictor import BasePredictor
#       6 from ultralytics.yolo.engine.results import Results
#       7 from ultralytics.yolo.utils import DEFAULT_CFG, ROOT
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\engine\predictor.py:37
#      34 import numpy as np
#      35 import torch
# ---> 37 from ultralytics.nn.autobackend import AutoBackend
#      38 from ultralytics.yolo.cfg import get_cfg
#      39 from ultralytics.yolo.data import load_inference_source
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\nn\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .tasks import (BaseModel, ClassificationModel, DetectionModel, SegmentationModel, attempt_load_one_weight,
#       4                     attempt_load_weights, guess_model_scale, guess_model_task, parse_model, torch_safe_load,
#       5                     yaml_model_load)
#       7 __all__ = ('attempt_load_one_weight', 'attempt_load_weights', 'parse_model', 'yaml_model_load', 'guess_model_task',
#       8            'guess_model_scale', 'torch_safe_load', 'DetectionModel', 'SegmentationModel', 'ClassificationModel',
#       9            'BaseModel')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\nn\tasks.py:10
#       7 import torch
#       8 import torch.nn as nn
# ---> 10 from ultralytics.nn.modules import (AIFI, C1, C2, C3, C3TR, SPP, SPPF, Bottleneck, BottleneckCSP, C2f, C3Ghost, C3x,
#      11                                     Classify, Concat, Conv, Conv2, ConvTranspose, Detect, DWConv, DWConvTranspose2d,
#      12                                     Focus, GhostBottleneck, GhostConv, HGBlock, HGStem, Pose, RepC3, RepConv,
#      13                                     RTDETRDecoder, Segment)
#      14 from ultralytics.yolo.utils import DEFAULT_CFG_DICT, DEFAULT_CFG_KEYS, LOGGER, colorstr, emojis, yaml_load
#      15 from ultralytics.yolo.utils.checks import check_requirements, check_suffix, check_yaml
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\nn\modules\__init__.py:20
#      16 from .block import (C1, C2, C3, C3TR, DFL, SPP, SPPF, Bottleneck, BottleneckCSP, C2f, C3Ghost, C3x, GhostBottleneck,
#      17                     HGBlock, HGStem, Proto, RepC3)
#      18 from .conv import (CBAM, ChannelAttention, Concat, Conv, Conv2, ConvTranspose, DWConv, DWConvTranspose2d, Focus,
#      19                    GhostConv, LightConv, RepConv, SpatialAttention)
# ---> 20 from .head import Classify, Detect, Pose, RTDETRDecoder, Segment
#      21 from .transformer import (AIFI, MLP, DeformableTransformerDecoder, DeformableTransformerDecoderLayer, LayerNorm2d,
#      22                           MLPBlock, MSDeformAttn, TransformerBlock, TransformerEncoderLayer, TransformerLayer)
#      24 __all__ = ('Conv', 'Conv2', 'LightConv', 'RepConv', 'DWConv', 'DWConvTranspose2d', 'ConvTranspose', 'Focus',
#      25            'GhostConv', 'ChannelAttention', 'SpatialAttention', 'CBAM', 'Concat', 'TransformerLayer',
#      26            'TransformerBlock', 'MLPBlock', 'LayerNorm2d', 'DFL', 'HGBlock', 'HGStem', 'SPP', 'SPPF', 'C1', 'C2', 'C3',
#      27            'C2f', 'C3x', 'C3TR', 'C3Ghost', 'GhostBottleneck', 'Bottleneck', 'BottleneckCSP', 'Proto', 'Detect',
#      28            'Segment', 'Pose', 'Classify', 'TransformerEncoderLayer', 'RepC3', 'RTDETRDecoder', 'AIFI',
#      29            'DeformableTransformerDecoder', 'DeformableTransformerDecoderLayer', 'MSDeformAttn', 'MLP')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\nn\modules\head.py:12
#       9 import torch.nn as nn
#      10 from torch.nn.init import constant_, xavier_uniform_
# ---> 12 from ultralytics.yolo.utils.tal import dist2bbox, make_anchors
#      14 from .block import DFL, Proto
#      15 from .conv import Conv
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\utils\__init__.py:766
#     762 # Run below code on yolo/utils init ------------------------------------------------------------------------------------
#     763
#     764 # Check first-install steps
#     765 PREFIX = colorstr('Ultralytics: ')
# --> 766 SETTINGS = get_settings()
#     767 DATASETS_DIR = Path(SETTINGS['datasets_dir'])  # global datasets directory
#     768 ENVIRONMENT = 'Colab' if is_colab() else 'Kaggle' if is_kaggle() else 'Jupyter' if is_jupyter() else \
#     769     'Docker' if is_docker() else platform.system()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\utils\__init__.py:699, in get_settings(file, version)
#     696 import hashlib
#     698 from ultralytics.yolo.utils.checks import check_version
# --> 699 from ultralytics.yolo.utils.torch_utils import torch_distributed_zero_first
#     701 git_dir = get_git_dir()
#     702 root = git_dir or Path()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\utils\torch_utils.py:18
#      16 import torch.nn as nn
#      17 import torch.nn.functional as F
# ---> 18 import torchvision
#      20 from ultralytics.yolo.utils import DEFAULT_CFG_DICT, DEFAULT_CFG_KEYS, LOGGER, RANK, __version__
#      21 from ultralytics.yolo.utils.checks import check_version
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\__init__.py:10
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#      13     from .version import __version__  # noqa: F401
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\convnext.py:9
#       6 from torch.nn import functional as F
#       8 from ..ops.misc import Conv2dNormActivation, Permute
# ----> 9 from ..ops.stochastic_depth import StochasticDepth
#      10 from ..transforms._presets import ImageClassification
#      11 from ..utils import _log_api_usage_once
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\ops\__init__.py:23
#      21 from .giou_loss import generalized_box_iou_loss
#      22 from .misc import Conv2dNormActivation, Conv3dNormActivation, FrozenBatchNorm2d, MLP, Permute, SqueezeExcitation
# ---> 23 from .poolers import MultiScaleRoIAlign
#      24 from .ps_roi_align import ps_roi_align, PSRoIAlign
#      25 from .ps_roi_pool import ps_roi_pool, PSRoIPool
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\ops\poolers.py:10
#       7 from torchvision.ops.boxes import box_area
#       9 from ..utils import _log_api_usage_once
# ---> 10 from .roi_align import roi_align
#      13 # copying result_idx_in_level to a specific index in result[]
#      14 # is not supported by ONNX tracing yet.
#      15 # _onnx_merge_levels() is an implementation supported by ONNX
#      16 # that merges the levels to the right indices
#      17 @torch.jit.unused
#      18 def _onnx_merge_levels(levels: Tensor, unmerged_results: List[Tensor]) -> Tensor:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\ops\roi_align.py:7
#       5 import torch.fx
#       6 from torch import nn, Tensor
# ----> 7 from torch._dynamo.utils import is_compile_supported
#       8 from torch.jit.annotations import BroadcastingList2
#       9 from torch.nn.modules.utils import _pair
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\_dynamo\__init__.py:13
#       1 """
#       2 TorchDynamo is a Python-level JIT compiler designed to make unmodified PyTorch programs faster.
#       3 TorchDynamo hooks into the frame evaluation API in CPython (PEP 523) to dynamically modify Python
#    (...)      8 seamlessly optimize PyTorch programs, including those using modern Python features.
#       9 """
#      11 import torch
# ---> 13 from . import config, convert_frame, eval_frame, resume_execution
#      14 from .backends.registry import list_backends, lookup_backend, register_backend
#      15 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\_dynamo\convert_frame.py:52
#      50 from torch._C._dynamo.guards import GlobalStateGuard
#      51 from torch._dynamo.distributed import get_compile_pg
# ---> 52 from torch._dynamo.symbolic_convert import TensorifyState
#      53 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      54 from torch._logging import structured
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\_dynamo\symbolic_convert.py:57
#      54 from torch.fx.experimental.symbolic_shapes import guard_bool
#      55 from torch.utils._functools import cache_method
# ---> 57 from . import (
#      58     config,
#      59     exc,
#      60     graph_break_hints,
#      61     logging as torchdynamo_logging,
#      62     trace_rules,
#      63     variables,
#      64 )
#      65 from .bytecode_analysis import (
#      66     get_indexof,
#      67     JUMP_OPNAMES,
#      68     livevars_analysis,
#      69     propagate_line_nums,
#      70 )
#      71 from .bytecode_transformation import (
#      72     cleaned_instructions,
#      73     create_call_function,
#    (...)     80     unique_id,
#      81 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\_dynamo\trace_rules.py:32
#      30 from .resume_execution import TORCH_DYNAMO_RESUME_IN_PREFIX
#      31 from .utils import getfile, hashable, NP_SUPPORTED_MODULES, unwrap_if_wrapper
# ---> 32 from .variables import (
#      33     BuiltinVariable,
#      34     FunctionalCallVariable,
#      35     FunctorchHigherOrderVariable,
#      36     LocalGeneratorFunctionVariable,
#      37     LocalGeneratorObjectVariable,
#      38     NestedUserFunctionVariable,
#      39     PolyfilledFunctionVariable,
#      40     SkipFunctionVariable,
#      41     TorchInGraphFunctionVariable,
#      42     UserFunctionVariable,
#      43     UserMethodVariable,
#      44 )
#      47 np: Optional[types.ModuleType] = None
#      48 try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\_dynamo\variables\__init__.py:19
#       1 """
#       2 This package implements variable tracking and symbolic execution capabilities for Dynamo,
#       3 which are essential for converting Python code into FX graphs. It provides a comprehensive
#    (...)     16 allows Dynamo to accurately trace and optimize Python code while preserving its semantics.
#      17 """
# ---> 19 from .base import VariableTracker
#      20 from .builtin import BuiltinVariable
#      21 from .constant import ConstantVariable, EnumVariable
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\_dynamo\variables\base.py:26
#      24 from ..current_scope_id import current_scope_id
#      25 from ..exc import unimplemented, unimplemented_v2
# ---> 26 from ..guards import GuardBuilder, install_guard
#      27 from ..source import AttrSource, Source
#      28 from ..utils import cmp_name_to_op_mapping, istype
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\_dynamo\guards.py:46
#      44 import torch.overrides
#      45 import torch.utils._device
# ---> 46 from torch._C._dynamo.eval_frame import code_framelocals_names
#      47 from torch._C._dynamo.guards import (
#      48     check_obj_id,
#      49     check_type_id,
#    (...)     57     RootGuardManager,
#      58 )
#      59 from torch._dynamo.source import (
#      60     IndexedSource,
#      61     is_from_flatten_script_object_source,
#    (...)     65     TensorPropertySource,
#      66 )
#
# ImportError: cannot import name 'code_framelocals_names' from 'torch._C._dynamo.eval_frame' (unknown location)

# %% [markdown]
# model = YOLO("yolov8m-pose.pt")
