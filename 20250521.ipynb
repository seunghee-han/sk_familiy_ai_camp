# %%
print("hello world!")
# Out:
# hello world!

# %%
import requests   #module, package
url = "https://www.starbucks.co.kr/store/getStore.do?r=86N465IIB2"
payload = {"in_biz_cds": "0",
"in_scodes": "0",
"ins_lat": "37.4745",
"ins_lng": "126.8918",
"search_text": "",
"p_sido_cd": "01",
"p_gugun_cd": "",
"in_distance": "0",
"in_biz_cd": "",
"isError": "true",
"searchType": "C",
"set_date": "",
"all_store": "0",
"T03": "0",
"T01": "0",
"T27": "0",
"T12": "0",
"T09": "0",
"T30": "0",
"T05": "0",
"T22": "0",
"T21": "0",
"T36": "0",
"T43": "0",
"Z9999": "0",
"T64": "0",
"T66": "0",
"P02": "0",
"P10": "0",
"P50": "0",
"P20": "0",
"P60": "0",
"P30": "0",
"P70": "0",
"P40": "0",
"P80": "0",
"whcroad_yn": "0",
"P90": "0",
"P01": "0",
"new_bool": "0",
"iend": "1000",
"rndCod": "XW4W0LA4X8",}
r = requests.post(url, data=payload)
star = r.json()

# %%
type(star)
# Out:
# dict

# %%
tmp={}
for x in 'abcdeaae':
    if x in tmp:
        tmp[x]=tmp[x]+1
    else:
        tmp[x]=1

# %%
star_list = star['list']
star_list[-1]['s_name']
for store in star_list:
    print(store['s_name'])
# Out:
# 역삼아레나빌딩
# 논현역사거리
# 신사역성일빌딩
# 국기원사거리
# 대치재경빌딩
# 봉은사역
# 압구정윤성빌딩
# 코엑스별마당
# 삼성역섬유센터R
# 압구정R
# 수서역R
# 양재강남빌딩R
# 선릉동신빌딩R
# 봉은사로선정릉
# 강남오거리
# 스타필드코엑스몰R
# 강남구청정문
# 도곡공원
# 강남R
# 대치은마사거리
# 청담영동대로
# 압구정
# 신사가로수
# 청담스타R
# 강남우성
# 학동사거리
# 대치사거리
# 포스코사거리
# 을지병원사거리
# 신사역
# 도곡역
# 서울세관사거리
# 청담사거리
# 한티역
# 역삼초교사거리
# 코엑스몰
# 가로수길
# 역삼대로
# 역삼포스코
# 강남대로
# 청담
# 삼성도심공항
# 삼성교
# 학동역
# 대치
# 신세계푸드마켓도곡
# 삼성
# 선릉세화빌딩
# 압구정역
# 압구정로
# 구역삼사거리
# 큰길타워
# 강남구청역
# 대치역
# 포이
# 아크플레이스
# 학여울역
# 선정릉역
# 삼성현대힐
# GS타워
# 압구정미소
# 선릉역
# 코엑스사거리
# 역삼럭키
# 신압구정
# 아크로힐스논현
# 강남비젼타워
# 압구정로데오역
# 르네상스사거리
# 포스코
# 선릉로
# 논현힐탑
# 도산가로수길
# 매봉역
# 대치한티
# 개포동
# 수서역사거리
# 코엑스아셈타워
# 센터필드R
# 도산사거리
# 강남세곡
# 대치삼성
# 언주역
# 강남역신분당역사
# 삼성역
# 테헤란로아남타워
# 강남논현
# 삼성동
# 리저브도산
# 압구정역사3번출구
# 청담역
# 압구정현대아파트
# 강남청담빌딩
# 역삼이마트
# 케이스퀘어강남
# 강남세곡DT
# 미아뉴타운
# 강북구청사거리
# 미아사거리역
# 수유역
# 미아역
# 수유역5번출구
# 파라스파라서울
# 발산역사거리
# 마곡역
# 우장산역
# 마곡사이언스타워R
# 방화DT
# 마곡나루역
# 마곡GMG
# 가양역
# 화곡DT
# 양천향교역
# 화곡동
# 등촌
# 염창역
# 발산역
# 까치산역
# 염창대로
# 발산역5번출구
# 화곡역8번출구
# 강서우장산
# 등촌대로
# 마곡보타닉게이트
# 가양역사거리
# ...

# %%
store
# Out:
# {'seq': 0,
#  'sido_cd': None,
#  'sido_nm': None,
#  'gugun_cd': None,
#  'gugun_nm': None,
#  'code_order': None,
#  'view_yn': None,
#  'store_num': None,
#  'sido': None,
#  'gugun': None,
#  'address': None,
#  'new_img_nm': None,
#  'p_pro_seq': 0,
#  'p_view_yn': None,
#  'p_sido_cd': '',
#  'p_gugun_cd': '',
#  'p_store_nm': None,
#  'p_theme_cd': None,
#  'p_wireless_yn': None,
#  'p_smoking_yn': None,
#  'p_book_yn': None,
#  'p_music_yn': None,
#  'p_terrace_yn': None,
#  'p_table_yn': None,
#  'p_takeout_yn': None,
#  'p_parking_yn': None,
#  'p_dollar_assent': None,
#  'p_card_recharge': None,
#  'p_subway_yn': None,
#  'stb_store_file_renew': None,
#  'stb_store_theme_renew': None,
#  'stb_store_time_renew': None,
#  'stb_store_lsm': None,
#  's_code': '1749',
#  's_name': '중화역',
#  'tel': '1522-3232',
#  'dlvry_call_cntr_phno': None,
#  'fax': '02-435-3802',
#  'sido_code': '01',
#  'sido_name': '서울',
#  'gugun_code': '0125',
#  'gugun_name': '중랑구',
# ...

# %%
store['gugun_name']
# Out:
# '중랑구'

# %%
name_list=[]
count={}
for store in star_list:
    name_list.append(store['gugun_name'])
# print(name_list)
for i in name_list:
    if i in count:
        count[i]+=1
    else:
        count[i]=1
print(count)
# Out:
# {'강남구': 96, '강북구': 7, '강서구': 32, '관악구': 13, '광진구': 19, '금천구': 14, '노원구': 15, '도봉구': 7, '동작구': 13, '마포구': 37, '서대문구': 21, '서초구': 52, '성북구': 17, '송파구': 37, '양천구': 17, '영등포구': 41, '은평구': 16, '종로구': 40, '중구': 50, '강동구': 20, '구로구': 14, '동대문구': 14, '성동구': 15, '용산구': 25, '중랑구': 9}

# %%
gugun = {}
for store in star['list']:
    if store['gugun_name'] in gugun:
        #gugun[store['gugun_name']] = gugun[store['gugun_name']] + 1
        gugun[store['gugun_name']] += 1
    else:
        # 초기값
        gugun[store['gugun_name']] = 1
print(gugun)
# Out:
# {'강남구': 96, '강북구': 7, '강서구': 32, '관악구': 13, '광진구': 19, '금천구': 14, '노원구': 15, '도봉구': 7, '동작구': 13, '마포구': 37, '서대문구': 21, '서초구': 52, '성북구': 17, '송파구': 37, '양천구': 17, '영등포구': 41, '은평구': 16, '종로구': 40, '중구': 50, '강동구': 20, '구로구': 14, '동대문구': 14, '성동구': 15, '용산구': 25, '중랑구': 9}

# %%
store['open_dt']
# Out:
# '20201222'

# %%
lyrics = """따사로운 햇살 속에서
종소리가 울려 퍼지네
뺨을 매만지는 바람
한숨만은 깊어져만 가고
저 멀리서 핑 도는 눈물
이름을 붙여준 내일
포개어지는 미래 빛 라인
천진난만한 이런 기분도
신이 나서 날아갈 정도로 웃었던 날도
사랑스럽고 소중하게 키울 수 있도록
어렵고 힘들었던 시간을 넘어서
아주 많은 처음을 주었잖아
이어져 가서는 닿기를
천진난만한 이런 기분도
신이 나서 날아갈 정도로 웃었던 날도
사랑스럽고 소중하게 키울 수 있도록
어렵고 힘들었던 시간을 넘어서
아주 많은 처음을 주었잖아
이어져 가서는
천진난만한 이런 기분도
신이 나서 날아갈 정도로 웃었던 날도
사랑스럽고 소중하게 키울 수 있도록
어렵고 힘들었던 시간을 넘어서
아주 많은 처음을 주었잖아
이어져 가서는
이어져 가서는 닿기를"""

# %%
lyrics.split()
# Out:
# ['따사로운',
#  '햇살',
#  '속에서',
#  '종소리가',
#  '울려',
#  '퍼지네',
#  '뺨을',
#  '매만지는',
#  '바람',
#  '한숨만은',
#  '깊어져만',
#  '가고',
#  '저',
#  '멀리서',
#  '핑',
#  '도는',
#  '눈물',
#  '이름을',
#  '붙여준',
#  '내일',
#  '포개어지는',
#  '미래',
#  '빛',
#  '라인',
#  '천진난만한',
#  '이런',
#  '기분도',
#  '신이',
#  '나서',
#  '날아갈',
#  '정도로',
#  '웃었던',
#  '날도',
#  '사랑스럽고',
#  '소중하게',
#  '키울',
#  '수',
#  '있도록',
#  '어렵고',
#  '힘들었던',
#  '시간을',
#  '넘어서',
#  '아주',
#  '많은',
#  '처음을',
#  '주었잖아',
#  '이어져',
#  '가서는',
#  '닿기를',
#  '천진난만한',
#  '이런',
#  '기분도',
#  '신이',
#  '나서',
#  '날아갈',
#  '정도로',
#  '웃었던',
#  '날도',
#  '사랑스럽고',
#  '소중하게',
#  '키울',
#  '수',
#  '있도록',
#  '어렵고',
#  '힘들었던',
#  '시간을',
#  '넘어서',
#  '아주',
#  '많은',
#  '처음을',
#  '주었잖아',
#  '이어져',
#  '가서는',
#  '천진난만한',
#  '이런',
#  '기분도',
#  '신이',
#  '나서',
#  '날아갈',
#  '정도로',
#  '웃었던',
#  '날도',
#  '사랑스럽고',
#  '소중하게',
#  '키울',
#  '수',
#  '있도록',
#  '어렵고',
#  '힘들었던',
#  '시간을',
#  '넘어서',
#  '아주',
#  '많은',
#  '처음을',
#  '주었잖아',
#  '이어져',
#  '가서는',
#  '이어져',
#  '가서는',
#  '닿기를']

# %%
a=[]
for i in lyrics.split():
    if len(i)>1:
        a.append(i)
print(a)
# Out:
# ['따사로운', '햇살', '속에서', '종소리가', '울려', '퍼지네', '뺨을', '매만지는', '바람', '한숨만은', '깊어져만', '가고', '멀리서', '도는', '눈물', '이름을', '붙여준', '내일', '포개어지는', '미래', '라인', '천진난만한', '이런', '기분도', '신이', '나서', '날아갈', '정도로', '웃었던', '날도', '사랑스럽고', '소중하게', '키울', '있도록', '어렵고', '힘들었던', '시간을', '넘어서', '아주', '많은', '처음을', '주었잖아', '이어져', '가서는', '닿기를', '천진난만한', '이런', '기분도', '신이', '나서', '날아갈', '정도로', '웃었던', '날도', '사랑스럽고', '소중하게', '키울', '있도록', '어렵고', '힘들었던', '시간을', '넘어서', '아주', '많은', '처음을', '주었잖아', '이어져', '가서는', '천진난만한', '이런', '기분도', '신이', '나서', '날아갈', '정도로', '웃었던', '날도', '사랑스럽고', '소중하게', '키울', '있도록', '어렵고', '힘들었던', '시간을', '넘어서', '아주', '많은', '처음을', '주었잖아', '이어져', '가서는', '이어져', '가서는', '닿기를']

# %%
cnt={}
for word in lyrics.split():
    if len(word)>1:
        if word in cnt:
            cnt[word]+=1
        else:
            cnt[word]=1

# %%
# sorted(cnt.items(),key=lambda x in ,False)
# Out:
#   Cell In[50], line 1
#     sorted(cnt.items(),key=lambda x in ,False)
#                                     ^
# SyntaxError: invalid syntax

# %%
store
# Out:
# {'seq': 0,
#  'sido_cd': None,
#  'sido_nm': None,
#  'gugun_cd': None,
#  'gugun_nm': None,
#  'code_order': None,
#  'view_yn': None,
#  'store_num': None,
#  'sido': None,
#  'gugun': None,
#  'address': None,
#  'new_img_nm': None,
#  'p_pro_seq': 0,
#  'p_view_yn': None,
#  'p_sido_cd': '',
#  'p_gugun_cd': '',
#  'p_store_nm': None,
#  'p_theme_cd': None,
#  'p_wireless_yn': None,
#  'p_smoking_yn': None,
#  'p_book_yn': None,
#  'p_music_yn': None,
#  'p_terrace_yn': None,
#  'p_table_yn': None,
#  'p_takeout_yn': None,
#  'p_parking_yn': None,
#  'p_dollar_assent': None,
#  'p_card_recharge': None,
#  'p_subway_yn': None,
#  'stb_store_file_renew': None,
#  'stb_store_theme_renew': None,
#  'stb_store_time_renew': None,
#  'stb_store_lsm': None,
#  's_code': '1749',
#  's_name': '중화역',
#  'tel': '1522-3232',
#  'dlvry_call_cntr_phno': None,
#  'fax': '02-435-3802',
#  'sido_code': '01',
#  'sido_name': '서울',
#  'gugun_code': '0125',
#  'gugun_name': '중랑구',
# ...

# %%
text="서울특별시 중랑구 중화동 306-68 중화동 HS빌딩 1,2층"

# %%
text
# Out:
# '서울특별시 중랑구 중화동 306-68 중화동 HS빌딩 1,2층'

# %%
text.find("중화동") #시작되는 인덱스값 return
# Out:
# 10

# %%
star_list
# Out:
# [{'seq': 0,
#   'sido_cd': None,
#   'sido_nm': None,
#   'gugun_cd': None,
#   'gugun_nm': None,
#   'code_order': None,
#   'view_yn': None,
#   'store_num': None,
#   'sido': None,
#   'gugun': None,
#   'address': None,
#   'new_img_nm': None,
#   'p_pro_seq': 0,
#   'p_view_yn': None,
#   'p_sido_cd': '',
#   'p_gugun_cd': '',
#   'p_store_nm': None,
#   'p_theme_cd': None,
#   'p_wireless_yn': None,
#   'p_smoking_yn': None,
#   'p_book_yn': None,
#   'p_music_yn': None,
#   'p_terrace_yn': None,
#   'p_table_yn': None,
#   'p_takeout_yn': None,
#   'p_parking_yn': None,
#   'p_dollar_assent': None,
#   'p_card_recharge': None,
#   'p_subway_yn': None,
#   'stb_store_file_renew': None,
#   'stb_store_theme_renew': None,
#   'stb_store_time_renew': None,
#   'stb_store_lsm': None,
#   's_code': '1509',
#   's_name': '역삼아레나빌딩',
#   'tel': '1522-3232',
#   'dlvry_call_cntr_phno': None,
#   'fax': '02-568-3763',
#   'sido_code': '01',
#   'sido_name': '서울',
# ...

# %%
#ver1
name_list=[]
count={}
for store in star_list:
    if "독산" in store['addr']:
        name_list.append(store['s_name'])
print(name_list)


#ver2
name_list=[]
count={}
for store in star_list:
    if store['addr'].find("가산") > -1:
        name_list.append(store['s_name'])
print(name_list)

# print(len(star_list))
# print(len(name_list))
# for i in name_list:
#     if i in count:
#         count[i]+=1
#     else:
#         count[i]=1
# print(count)
# Out:
# ['독산사거리', '금천독산']
# ['가산에스케이', '가산디지털단지역', '가산디지털', '마리오아울렛', '가산브이타워', '독산역', '가산퍼블릭', '가산현대아울렛', '가산케이에스', '가산어반워크']

# %%
def get_starbucks(dong):
    name_list=[]
    for store in star_list:
        if dong in store['addr']:
            print(dong)

# %%
def multi(x,y,type_):
    if type_=='add':
        return (x+y)
    if type_ =='multi':
        return(x*y)

# %%
result=multi(3,4,"multi")
result
# Out:
# 12

# %%
#bmi =체중/(키*키)
def bmi(kg,cm):
    m=cm*0.01
    return kg/(m*m)
    # return kg/(cm/100)**2

# %%
(lambda kg,cm: kg/(cm/100)**2)(70,180)
# Out:
# 21.604938271604937

# %%
import datetime

# %%
for day in range(100,1001,100):
    print(datetime.datetime.today()+datetime.timedelta(days=day),end='--> ')
    print((datetime.datetime.today()+datetime.timedelta(days=day)).weekday())
# Out:
# 2025-08-29 12:28:10.147480--> 4
# 2025-12-07 12:28:10.148480--> 6
# 2026-03-17 12:28:10.148480--> 1
# 2026-06-25 12:28:10.148480--> 3
# 2026-10-03 12:28:10.148480--> 5
# 2027-01-11 12:28:10.148480--> 0
# 2027-04-21 12:28:10.148480--> 2
# 2027-07-30 12:28:10.148480--> 4
# 2027-11-07 12:28:10.148480--> 6
# 2028-02-15 12:28:10.148480--> 1

# %%
store['open_dt']
# Out:
# '20201222'

# %%
datetime.datetime.strptime( store['open_dt'], "%Y%m%d" ).weekday()
# Out:
# 1

# %%
#오픈한 스타벅스 날짜 월~일 중 오픈 가장 많이한 요일은?
days={}
for store in star['list']:
    j=dict(zip(range(0,7),"월화수목금토일"))[datetime.datetime.strptime(store['open_dt'], "%Y%m%d").weekday()]
    if j in days:
        days[j]+=1
    else:
        days[j]=1


sorted(days.items(), key=lambda x:x[1],reverse=True)
# Out:
# [('목', 175), ('금', 159), ('화', 128), ('수', 126), ('월', 42), ('토', 6), ('일', 5)]

# %%
# 절대경로
# c:\Users\Playdata\Desktop\code\workspace
# 상대경로
# .\workspace

# !dir
# Out:
#  C ����̺��� �������� �̸��� �����ϴ�.
#  ���� �Ϸ� ��ȣ: 382E-C517
#
#  c:\Users\Playdata\Desktop\code\workspace ���͸�
#
# 2025-05-21  ���� 02:05    <DIR>          .
# 2025-05-21  ���� 09:11    <DIR>          ..
# 2025-05-21  ���� 12:13         2,961,518 20250521.ipynb
# 2025-05-21  ���� 02:04             7,224 kbo_2024.pkl
#                2�� ����           2,968,742 ����Ʈ
#                2�� ���͸�  429,007,015,936 ����Ʈ ����

# %%
import pickle
with open("./data/kbo_2024.pkl","rb") as f:
#with open(r"./data/kbo_2024.pkl","rb") as f:

    kbo=pickle.load(f)

# %%
kbo
# Out:
# ['54607',
#  '54613',
#  '67604',
#  '68069',
#  '61353',
#  '53609',
#  '51640',
#  '76225',
#  '66614',
#  '69620',
#  '60337',
#  '52605',
#  '53618',
#  '69745',
#  '54614',
#  '69627',
#  '54608',
#  '54645',
#  '63894',
#  '67610',
#  '78603',
#  '66492',
#  '51666',
#  '68659',
#  '53619',
#  '52661',
#  '78122',
#  '54609',
#  '69516',
#  '65653',
#  '62947',
#  '54640',
#  '51645',
#  '50657',
#  '52634',
#  '54616',
#  '67609',
#  '63638',
#  '64646',
#  '69727',
#  '78168',
#  '54610',
#  '52630',
#  '52642',
#  '54664',
#  '77637',
#  '68330',
#  '50622',
#  '69636',
#  '68614',
#  '67640',
#  '50604',
#  '52667',
#  '53613',
#  '68619',
#  '53615',
#  '54644',
#  '52647',
#  '53663',
#  '51668',
#  '51605',
#  '63260',
#  '51648',
#  '51602',
#  '65665',
#  '64560',
#  '62951',
#  '62754',
#  '66833',
#  '51665',
#  '51603',
#  '50641',
#  '63950',
#  '66609',
#  '50662',
#  '53659',
#  '54667',
#  '66354',
#  '66807',
#  '66606',
#  '65464',
#  '52639',
#  '54611',
# ...

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Playdata\\Desktop\\code\\workspace'

# %%
with open("../../../Downloads/kbo.csv",'r',encoding='utf-8') as f:
    data=f.read()

# %%
print(data)
# Out:
# 선수명,등번호,생년월일,포지션,신장/체중,경력,입단 계약금,연봉,지명순위,입단년도,Team
# 강민,No.100,2001년 04월 20일,투수(우투우타),188cm/88kg,수유초-홍은중-서울고,8000만원,3000만원,20 LG 2차 4라운드 33순위,,LG 트윈스
# 고영웅,No.116,2004년 07월 29일,투수(좌투좌타),180cm/90kg,태전초(경기광주시리틀)-모가중-야로고BC-동원대,3000만원,3000만원,25 LG 10라운드 100순위,,LG 트윈스
# 구본혁,No.6,1997년 01월 11일,내야수(우투우타),177cm/75kg,중대초-잠신중-장충고-동국대-LG-상무,5000만원,13500만원,19 LG 2차 6라운드 55순위,19LG,LG 트윈스
# 김강률,No.37,1988년 08월 28일,투수(우투우타),187cm/95kg,문촌초(일산리틀)-장성중-경기고-두산-상무-두산,8000만원,10000만원,07 두산 2차 4라운드 26순위,07두산,LG 트윈스
# 김대현,No.12,1997년 03월 08일,투수(우투우타),188cm/100kg,홍연초(마포구리틀)-홍은중-선린인터넷고,27000만원,7500만원,16 LG 1차,16LG,LG 트윈스
# 김도윤,No.107,2005년 02월 17일,내야수(우투우타),180cm/71kg,화중초(덕양구리틀)-경기신일중-야탑고,3000만원,3000만원,24 LG 10라운드 98순위,,LG 트윈스
# 김민수,No.16,1998년 03월 18일,내야수(우투우타),184cm/97kg,서화초-동산중-제물포고-롯데-경찰-롯데,11000만원,6000만원,17 롯데 2차 2라운드 13순위,17롯데,LG 트윈스
# 김범석,No.55,2004년 05월 21일,포수(우투우타),178cm/110kg,김해삼성초-경남중-경남고,25000만원,4700만원,23 LG 1라운드 7순위,23LG,LG 트윈스
# ...

# %%
for x in data.split("\n")[1:-1]:
    print(x.split(","))
    # break
# Out:
# ['강민', 'No.100', '2001년 04월 20일', '투수(우투우타)', '188cm/88kg', '수유초-홍은중-서울고', '8000만원', '3000만원', '20 LG 2차 4라운드 33순위', '', 'LG 트윈스']
# ['고영웅', 'No.116', '2004년 07월 29일', '투수(좌투좌타)', '180cm/90kg', '태전초(경기광주시리틀)-모가중-야로고BC-동원대', '3000만원', '3000만원', '25 LG 10라운드 100순위', '', 'LG 트윈스']
# ['구본혁', 'No.6', '1997년 01월 11일', '내야수(우투우타)', '177cm/75kg', '중대초-잠신중-장충고-동국대-LG-상무', '5000만원', '13500만원', '19 LG 2차 6라운드 55순위', '19LG', 'LG 트윈스']
# ['김강률', 'No.37', '1988년 08월 28일', '투수(우투우타)', '187cm/95kg', '문촌초(일산리틀)-장성중-경기고-두산-상무-두산', '8000만원', '10000만원', '07 두산 2차 4라운드 26순위', '07두산', 'LG 트윈스']
# ['김대현', 'No.12', '1997년 03월 08일', '투수(우투우타)', '188cm/100kg', '홍연초(마포구리틀)-홍은중-선린인터넷고', '27000만원', '7500만원', '16 LG 1차', '16LG', 'LG 트윈스']
# ['김도윤', 'No.107', '2005년 02월 17일', '내야수(우투우타)', '180cm/71kg', '화중초(덕양구리틀)-경기신일중-야탑고', '3000만원', '3000만원', '24 LG 10라운드 98순위', '', 'LG 트윈스']
# ...

# %%
col=data.split('\n')[0].split(",")
col
# Out:
# ['선수명',
#  '등번호',
#  '생년월일',
#  '포지션',
#  '신장/체중',
#  '경력',
#  '입단 계약금',
#  '연봉',
#  '지명순위',
#  '입단년도',
#  'Team']

# %%
# Out:
# 광주수창초-진흥중-진흥고-히어로즈

# %%
dict(zip(col,data.split("\n")[1].split(",")))
# Out:
# {'선수명': '강민',
#  '등번호': 'No.100',
#  '생년월일': '2001년 04월 20일',
#  '포지션': '투수(우투우타)',
#  '신장/체중': '188cm/88kg',
#  '경력': '수유초-홍은중-서울고',
#  '입단 계약금': '8000만원',
#  '연봉': '3000만원',
#  '지명순위': '20 LG 2차 4라운드 33순위',
#  '입단년도': '',
#  'Team': 'LG 트윈스'}

# %%
kbo_list=[]
for x in data.split("\n")[1:-1]:
    kbo_list.append(dict(zip(col,x.split(","))))
kbo_list

# %%
kbo_list
# Out:
# [{'선수명': '강민',
#   '등번호': 'No.100',
#   '생년월일': '2001년 04월 20일',
#   '포지션': '투수(우투우타)',
#   '신장/체중': '188cm/88kg',
#   '경력': '수유초-홍은중-서울고',
#   '입단 계약금': '8000만원',
#   '연봉': '3000만원',
#   '지명순위': '20 LG 2차 4라운드 33순위',
#   '입단년도': '',
#   'Team': 'LG 트윈스'},
#  {'선수명': '고영웅',
#   '등번호': 'No.116',
#   '생년월일': '2004년 07월 29일',
#   '포지션': '투수(좌투좌타)',
#   '신장/체중': '180cm/90kg',
#   '경력': '태전초(경기광주시리틀)-모가중-야로고BC-동원대',
#   '입단 계약금': '3000만원',
#   '연봉': '3000만원',
#   '지명순위': '25 LG 10라운드 100순위',
#   '입단년도': '',
#   'Team': 'LG 트윈스'},
#  {'선수명': '구본혁',
#   '등번호': 'No.6',
#   '생년월일': '1997년 01월 11일',
#   '포지션': '내야수(우투우타)',
#   '신장/체중': '177cm/75kg',
#   '경력': '중대초-잠신중-장충고-동국대-LG-상무',
#   '입단 계약금': '5000만원',
#   '연봉': '13500만원',
#   '지명순위': '19 LG 2차 6라운드 55순위',
#   '입단년도': '19LG',
#   'Team': 'LG 트윈스'},
#  {'선수명': '김강률',
#   '등번호': 'No.37',
#   '생년월일': '1988년 08월 28일',
#   '포지션': '투수(우투우타)',
#   '신장/체중': '187cm/95kg',
#   '경력': '문촌초(일산리틀)-장성중-경기고-두산-상무-두산',
#   '입단 계약금': '8000만원',
# ...

# %%
height,weight= '180cm/71kg'.split("/")
height = height.replace("cm","")
weight = weight.replace("kg","")
weight
# Out:
# '71'

# %%
kbo_list2 = [dict(zip(col, x.split(","))) for x in data.split("\n")[1:-1]]

# %%
for player in  kbo_list:
    height, weight = player['신장/체중'].split("/")
    height = height.replace("cm", "")
    weight = weight.replace("kg", "")
    try:
        player['weight'] = int(weight)
        player['height'] = int(height)
    except:
        player['weight'] = ''
        player['height'] = ''

# %%
player
# Out:
# '광주수창초-진흥중-진흥고-히어로즈'

# %%
career=[]
a=[]
count={}
for i in range(len(kbo_list2)):
    career.append(kbo_list2[i]['경력'])
for j in range(len(career)):
    a.append((career[j].split("-"))[0])
for j in a:
    if j in count:
        count[j]+=1
    else:
        count[j]=1
max(count,key=count.get)
# Out:
# '가동초'

# %%
for player in kbo_list:
    if len(player['경력'])<5:
        print(player)
# Out:
# {'선수명': '플로리얼', '등번호': 'No.34', '생년월일': '1997년 11월 25일', '포지션': '외야수(우투좌타)', '신장/체중': '185cm/88kg', '경력': '도미니카', '입단 계약금': '50000달러', '연봉': '700000달러', '지명순위': '25 한화 자유선발', '입단년도': '25한화', 'Team': '한화 이글스'}

# %%
[x for x in player['경력'].split("-") if x[-1] =='초']
# Out:
# ['광주수창초']

# %%
player['경력'].split("-")[0]
# Out:
# '광주수창초'

# %%
for player in kbo_list:
    player['초등']=player['경력'].split("-")[0]

# %%
from collections import Counter

# %%
Counter([player['초등'] for player in kbo_list])
# Out:
# Counter({'가동초': 19,
#          '부산수영초': 15,
#          '양정초': 14,
#          '송정동초': 14,
#          '광주대성초': 14,
#          '광주수창초': 13,
#          '대구옥산초': 13,
#          '성동초': 11,
#          '광주서석초': 11,
#          '양덕초': 11,
#          '수원신곡초': 10,
#          '광주화정초': 10,
#          '본리초': 10,
#          '서울도곡초': 10,
#          '동막초': 9,
#          '학강초': 9,
#          '대전신흥초': 9,
#          '역삼초': 9,
#          '김해삼성초': 8,
#          '화곡초': 8,
#          '군산중앙초': 8,
#          '칠성초': 8,
#          '순천북초': 8,
#          '효제초': 8,
#          '서울청구초': 8,
#          '수유초': 7,
#          '서화초': 7,
#          '연현초': 7,
#          '서울학동초': 7,
#          '인천숭의초': 7,
#          '길동초': 7,
#          '고명초': 7,
#          '화순초': 7,
#          '인천서림초': 7,
#          '남도초': 6,
#          '서흥초': 6,
#          '온양온천초': 6,
#          '서울이수초': 6,
#          '신도초': 6,
#          '강남초': 6,
#          '도신초': 6,
#          '광주서림초': 6,
#          '중대초': 5,
#          '울산대현초': 5,
#          '인헌초': 5,
# ...
